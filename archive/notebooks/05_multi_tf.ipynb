# %%
# Load params (prefer experiment params if present)
params_path = Path('config') / 'params.yaml'
# Placeholder: notebooks should replace this with run-specific params
print('Params path:', params_path)

# %%
import json
from pathlib import Path
from datetime import datetime, timezone

import pandas as pd

from src.core.timeframes import load_timeframe_windows, get_time_window
from src.core.experiment_registry import create_experiment

# %% [markdown]
# # 05 – Multi-Timeframe Hierarchy
# Scaffold for multi-timeframe hierarchy and interactions.
